# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a69013be9f0> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
# Check the versions of libraries
 
# Python version
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.6.2 |Anaconda, Inc.| (default, Sep 21 2017, 18:29:43)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# scipy: 0.19.1
# numpy: 1.13.1
# matplotlib: 2.0.2
# pandas: 0.20.3
# sklearn: 0.19.0

# %%
# Load libraries
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
dataset = np.loadtxt('baseball.csv', delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f26a2026d283> in <module>()
# ----> 1 dataset = np.loadtxt('baseball.csv', delimiter=",")
#
# NameError: name 'np' is not defined

# %%
dataset=pandas.read_csv("/Users/michaelcalderon/baseball.csv")

# %%
dataset
# Out:
#                                        Name Team          Position  Height  \
# 0                             Adam_Donachie  BAL           Catcher    74.0
# 1                                 Paul_Bako  BAL           Catcher    74.0
# 2                           Ramon_Hernandez  BAL           Catcher    72.0
# 3                              Kevin_Millar  BAL     First_Baseman    72.0
# 4                               Chris_Gomez  BAL     First_Baseman    73.0
# 5                             Brian_Roberts  BAL    Second_Baseman    69.0
# 6                             Miguel_Tejada  BAL         Shortstop    69.0
# 7                               Melvin_Mora  BAL     Third_Baseman    71.0
# 8                               Aubrey_Huff  BAL     Third_Baseman    76.0
# 9                                Adam_Stern  BAL        Outfielder    71.0
# 10                          Jeff_Fiorentino  BAL        Outfielder    73.0
# ...

# %%
# load dataset
dataset=pandas.read_csv("/Users/michaelcalderon/baseball.csv")
# update is available as 2D Numpy array

# Import numpy package
import numpy as np

# Create np_baseball (3 cols)
np_baseball = np.array(baseball)

# Print out addition of np_baseball and update
print(np_baseball + update)

# Create Numpy array: conversion
conversion=np.array([0.0254, 0.453592 , 1])

# Print out product of np_baseball and conversion
print(np_baseball * conversion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dbd559a93361> in <module>()
#       7
#       8 # Create np_baseball (3 cols)
# ----> 9 np_baseball = np.array(baseball)
#      10
#      11 # Print out addition of np_baseball and update
#
# NameError: name 'baseball' is not defined

# %%
# load dataset called baseball
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv")
# update is available as 2D Numpy array

# Import numpy package
import numpy as np

# Create np_baseball (3 cols)
np_baseball = np.array(baseball)

# Print out addition of np_baseball and update
print(np_baseball + update)

# Create Numpy array: conversion
conversion=np.array([0.0254, 0.453592 , 1])

# Print out product of np_baseball and conversion
print(np_baseball * conversion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-44a70db9e10d> in <module>()
#      10
#      11 # Print out addition of np_baseball and update
# ---> 12 print(np_baseball + update)
#      13
#      14 # Create Numpy array: conversion
#
# NameError: name 'update' is not defined

# %%
# load dataset called baseball
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv")
# update is available as 2D Numpy array

# Import numpy package
import numpy as np

# Create np_baseball (3 cols)
np_baseball = np.array(baseball)

# Print out addition of np_baseball and update
print(np_baseball)

# Create Numpy array: conversion
conversion=np.array([0.0254, 0.453592 , 1])

# Print out product of np_baseball and conversion
print(np_baseball * conversion)
# Out:
# [['Adam_Donachie' 'BAL' 'Catcher' ..., 180.0 22.99 'Catcher']
#  ['Paul_Bako' 'BAL' 'Catcher' ..., 215.0 34.69 'Catcher']
#  ['Ramon_Hernandez' 'BAL' 'Catcher' ..., 210.0 30.78 'Catcher']
#  ...,
#  ['Josh_Kinney' 'STL' 'Relief_Pitcher' ..., 195.0 27.92 'Pitcher']
#  ['</pre></body></html>Ztext/plainUUTF-8' nan nan ..., nan nan nan]
#  [nan nan nan ..., nan nan nan]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c89bfddb090a> in <module>()
#      16
#      17 # Print out product of np_baseball and conversion
# ---> 18 print(np_baseball * conversion)
#
# ValueError: operands could not be broadcast together with shapes (1017,7) (3,)

# %%
# load dataset
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv")
# Import numpy package
import numpy as np

# Create np_baseball (2 cols)
np_baseball = np.array(baseball)

# Print out the 50th row of np_baseball
print(np_baseball[49])
# Select the entire second column of np_baseball: np_weight
np_weight=np_baseball[ : , 1]
# Print out height of 124th player
print(np_baseball[123,0])
# Out:
# ['Rob_Mackowiak' 'CWS' 'Outfielder' 70.0 195.0 30.69 'Outfielder']
# Kason_Gabbard

# %%
# load dataset
import pandas
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv")

# np_baseball is available
np_baseball = np.array(baseball)

# Import numpy
import numpy as np

# Create np_height from np_baseball
np_height=np_baseball[:,0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
print(np.median(np_height))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-151a5268581b> in <module>()
#      13
#      14 # Print out the mean of np_height
# ---> 15 print(np.mean(np_height))
#      16
#      17 # Print out the median of np_height
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2907
#    2908     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2909                           out=out, **kwargs)
#    2910
#    2911
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: must be str, not float

# %%
help(read_csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-abd132b9e4e4> in <module>()
# ----> 1 help(read_csv)
#
# NameError: name 'read_csv' is not defined

# %%
# ?read_csv
# Out:
# Object `read_csv` not found.

# %%
# load dataset
import pandas
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols=3)

# np_baseball is available
np_baseball = np.array(baseball)

# Import numpy
import numpy as np

# Create np_height from np_baseball
np_height=np_baseball[:,0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
print(np.median(np_height))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b3a61521942e> in <module>()
#       1 # load dataset
#       2 import pandas
# ----> 3 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols=3)
#       4
#       5 # np_baseball is available
#
# ...

# %%
# load dataset
import pandas
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", header=1, usecols=3)

# np_baseball is available
np_baseball = np.array(baseball)

# Import numpy
import numpy as np

# Create np_height from np_baseball
np_height=np_baseball[:,0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
print(np.median(np_height))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5bcdc1e0c28e> in <module>()
#       1 # load dataset
#       2 import pandas
# ----> 3 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", header=1, usecols=3)
#       4
#       5 # np_baseball is available
#
# ...

# %%
# load dataset
import pandas
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", header=0, usecols=3)

# np_baseball is available
np_baseball = np.array(baseball)

# Import numpy
import numpy as np

# Create np_height from np_baseball
np_height=np_baseball[:,0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
print(np.median(np_height))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-846b2413f257> in <module>()
#       1 # load dataset
#       2 import pandas
# ----> 3 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", header=0, usecols=3)
#       4
#       5 # np_baseball is available
#
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", header=0, usecols=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0a4232f9abc8> in <module>()
# ----> 1 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", header=0, usecols=3)
#
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv")

# %%
baseball
# Out:
#                                        Name Team          Position  Height  \
# 0                             Adam_Donachie  BAL           Catcher    74.0
# 1                                 Paul_Bako  BAL           Catcher    74.0
# 2                           Ramon_Hernandez  BAL           Catcher    72.0
# 3                              Kevin_Millar  BAL     First_Baseman    72.0
# 4                               Chris_Gomez  BAL     First_Baseman    73.0
# 5                             Brian_Roberts  BAL    Second_Baseman    69.0
# 6                             Miguel_Tejada  BAL         Shortstop    69.0
# 7                               Melvin_Mora  BAL     Third_Baseman    71.0
# 8                               Aubrey_Huff  BAL     Third_Baseman    76.0
# 9                                Adam_Stern  BAL        Outfielder    71.0
# 10                          Jeff_Fiorentino  BAL        Outfielder    73.0
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4030264450c8> in <module>()
# ----> 1 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols=3)
#
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols="Height")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-459d9099cf0b> in <module>()
# ----> 1 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols="Height")
#
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False)

# %%
baseball
# Out:
#                                        Name Team          Position  Height  \
# 0                             Adam_Donachie  BAL           Catcher    74.0
# 1                                 Paul_Bako  BAL           Catcher    74.0
# 2                           Ramon_Hernandez  BAL           Catcher    72.0
# 3                              Kevin_Millar  BAL     First_Baseman    72.0
# 4                               Chris_Gomez  BAL     First_Baseman    73.0
# 5                             Brian_Roberts  BAL    Second_Baseman    69.0
# 6                             Miguel_Tejada  BAL         Shortstop    69.0
# 7                               Melvin_Mora  BAL     Third_Baseman    71.0
# 8                               Aubrey_Huff  BAL     Third_Baseman    76.0
# 9                                Adam_Stern  BAL        Outfielder    71.0
# 10                          Jeff_Fiorentino  BAL        Outfielder    73.0
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False)

# %%
baseball
# Out:
#                                        Name Team          Position  Height  \
# 0                             Adam_Donachie  BAL           Catcher    74.0
# 1                                 Paul_Bako  BAL           Catcher    74.0
# 2                           Ramon_Hernandez  BAL           Catcher    72.0
# 3                              Kevin_Millar  BAL     First_Baseman    72.0
# 4                               Chris_Gomez  BAL     First_Baseman    73.0
# 5                             Brian_Roberts  BAL    Second_Baseman    69.0
# 6                             Miguel_Tejada  BAL         Shortstop    69.0
# 7                               Melvin_Mora  BAL     Third_Baseman    71.0
# 8                               Aubrey_Huff  BAL     Third_Baseman    76.0
# 9                                Adam_Stern  BAL        Outfielder    71.0
# 10                          Jeff_Fiorentino  BAL        Outfielder    73.0
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecol= 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-43a422addba5> in <module>()
# ----> 1 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecol= 3)
#
# TypeError: parser_f() got an unexpected keyword argument 'usecol'

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecols= 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-36d8830971cd> in <module>()
# ----> 1 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecols= 3)
#
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecols= "Height")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b11445a480fe> in <module>()
# ----> 1 baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecols= "Height")
#
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, header= 3)

# %%
baseball
# Out:
#                             Ramon_Hernandez  BAL           Catcher    72  \
# 0                              Kevin_Millar  BAL     First_Baseman  72.0
# 1                               Chris_Gomez  BAL     First_Baseman  73.0
# 2                             Brian_Roberts  BAL    Second_Baseman  69.0
# 3                             Miguel_Tejada  BAL         Shortstop  69.0
# 4                               Melvin_Mora  BAL     Third_Baseman  71.0
# 5                               Aubrey_Huff  BAL     Third_Baseman  76.0
# 6                                Adam_Stern  BAL        Outfielder  71.0
# 7                           Jeff_Fiorentino  BAL        Outfielder  73.0
# 8                             Freddie_Bynum  BAL        Outfielder  73.0
# 9                             Nick_Markakis  BAL        Outfielder  74.0
# 10                            Brandon_Fahey  BAL        Outfielder  74.0
# 11                          Corey_Patterson  BAL        Outfielder  69.0
# ...

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols= [3])

# %%
baseball
# Out:
#       Height
# 0       74.0
# 1       74.0
# 2       72.0
# 3       72.0
# 4       73.0
# 5       69.0
# 6       69.0
# 7       71.0
# 8       76.0
# 9       71.0
# 10      73.0
# 11      73.0
# 12      74.0
# 13      74.0
# 14      69.0
# 15      70.0
# 16      73.0
# 17      75.0
# 18      78.0
# 19      79.0
# 20      76.0
# 21      74.0
# 22      76.0
# 23      72.0
# 24      71.0
# 25      75.0
# 26      77.0
# 27      74.0
# 28      73.0
# 29      74.0
# ...      ...
# 987     73.0
# 988     67.0
# 989     67.0
# 990     76.0
# 991     74.0
# 992     73.0
# 993     70.0
# 994     75.0
# 995     70.0
# 996     72.0
# 997     77.0
# 998     79.0
# 999     78.0
# 1000    74.0
# 1001    75.0
# 1002    75.0
# 1003    78.0
# 1004    76.0
# 1005    75.0
# 1006    69.0
# 1007    75.0
# 1008    72.0
# 1009    75.0
# 1010    73.0
# 1011    74.0
# 1012    75.0
# 1013    75.0
# 1014    73.0
# 1015     NaN
# 1016     NaN
#
# [1017 rows x 1 columns]

# %%
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols= [3])

# %%
baseball
# Out:
#       Height
# 0       74.0
# 1       74.0
# 2       72.0
# 3       72.0
# 4       73.0
# 5       69.0
# 6       69.0
# 7       71.0
# 8       76.0
# 9       71.0
# 10      73.0
# 11      73.0
# 12      74.0
# 13      74.0
# 14      69.0
# 15      70.0
# 16      73.0
# 17      75.0
# 18      78.0
# 19      79.0
# 20      76.0
# 21      74.0
# 22      76.0
# 23      72.0
# 24      71.0
# 25      75.0
# 26      77.0
# 27      74.0
# 28      73.0
# 29      74.0
# ...      ...
# 987     73.0
# 988     67.0
# 989     67.0
# 990     76.0
# 991     74.0
# 992     73.0
# 993     70.0
# 994     75.0
# 995     70.0
# 996     72.0
# 997     77.0
# 998     79.0
# 999     78.0
# 1000    74.0
# 1001    75.0
# 1002    75.0
# 1003    78.0
# 1004    76.0
# 1005    75.0
# 1006    69.0
# 1007    75.0
# 1008    72.0
# 1009    75.0
# 1010    73.0
# 1011    74.0
# 1012    75.0
# 1013    75.0
# 1014    73.0
# 1015     NaN
# 1016     NaN
#
# [1017 rows x 1 columns]

# %%
# load dataset
import pandas
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", usecols= [3])

# np_baseball is available
np_baseball = np.array(baseball)

# Import numpy
import numpy as np

# Create np_height from np_baseball
np_height=np_baseball[:,0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
print(np.median(np_height))
# Out:
# nan
# nan
# /Users/michaelcalderon/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)

# %%
# load dataset
import pandas
baseball=pandas.read_csv("/Users/michaelcalderon/baseball.csv", index_col= False, usecols= [3])

# Import numpy
import numpy as np

# define np_baseball
np_baseball = np.array(baseball)

# Create np_height from np_baseball
np_height=np_baseball[:,0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
# print(np.median(np_height))
# Out:
# nan

# %%
np_height
# Out:
# array([ 74.,  74.,  72., ...,  73.,  nan,  nan])

# %%
baseball
# Out:
#       Height
# 0       74.0
# 1       74.0
# 2       72.0
# 3       72.0
# 4       73.0
# 5       69.0
# 6       69.0
# 7       71.0
# 8       76.0
# 9       71.0
# 10      73.0
# 11      73.0
# 12      74.0
# 13      74.0
# 14      69.0
# 15      70.0
# 16      73.0
# 17      75.0
# 18      78.0
# 19      79.0
# 20      76.0
# 21      74.0
# 22      76.0
# 23      72.0
# 24      71.0
# 25      75.0
# 26      77.0
# 27      74.0
# 28      73.0
# 29      74.0
# ...      ...
# 987     73.0
# 988     67.0
# 989     67.0
# 990     76.0
# 991     74.0
# 992     73.0
# 993     70.0
# 994     75.0
# 995     70.0
# 996     72.0
# 997     77.0
# 998     79.0
# 999     78.0
# 1000    74.0
# 1001    75.0
# 1002    75.0
# 1003    78.0
# 1004    76.0
# 1005    75.0
# 1006    69.0
# 1007    75.0
# 1008    72.0
# 1009    75.0
# 1010    73.0
# 1011    74.0
# 1012    75.0
# 1013    75.0
# 1014    73.0
# 1015     NaN
# 1016     NaN
#
# [1017 rows x 1 columns]
